# %%
# %pip install neurokit2 seaborn
# !pip install neurokit2 ecg-plot

import neurokit2 as nk

import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

import ecg_plot

#ecg = nk.ecg_simulate(duration=10, sampling_rate=250, noise=0.2)

#ecg += np.random.normal(0, 0.1, len(ecg))

#ECG_CLEAN
ecg= np.loadtxt(r"C:\Users\Joaquin\Desktop\Repositorio Señales\ISB-Grupo-5\Otros\Archivos_varios\Lab5_ECG\EjercicioD1.txt", comments='#',skiprows=4, usecols=5)
filtered= nk.ecg_clean(ecg, sampling_rate=250, method="neurokit")

signals = pd.DataFrame({
    "ECG_Raw" : ecg,
    "ECG_NeuroKit" : nk.ecg_clean(ecg, sampling_rate=250, method="neurokit"),
    #"ECG_BioSPPy" : nk.ecg_clean(ecg, sampling_rate=250, method="biosppy"),
    #"ECG_PanTompkins" : nk.ecg_clean(ecg, sampling_rate=250, method="pantompkins1985"),
    #"ECG_Hamilton" : nk.ecg_clean(ecg, sampling_rate=250, method="hamilton2002"),
    #"ECG_Elgendi" : nk.ecg_clean(ecg, sampling_rate=250, method="elgendi2010"),
    #"ECG_EngZeeMod" : nk.ecg_clean(ecg, sampling_rate=250, method="engzeemod2012"),
    #"ECG_VG" : nk.ecg_clean(ecg, sampling_rate=250, method="vg"),
    #"ECG_TC" : nk.ecg_clean(ecg, sampling_rate=250, method="templateconvolution")
})

signals.plot(subplots=True)

#ECG_PROCESS
signals, info = nk.ecg_process(filtered, sampling_rate=250)
signals2 = signals[["ECG_Raw","ECG_Clean","ECG_Rate","ECG_Quality","ECG_R_Peaks","ECG_P_Peaks","ECG_Q_Peaks","ECG_S_Peaks","ECG_T_Peaks"]]
signals2.plot(subplots=True)

#ANALYZE
analysis = nk.ecg_analyze(signals, sampling_rate=250, method='auto')
analysis = analysis.transpose().reset_index  
display(analysis)

#ECG Rpeaks
signalsR, info = nk.ecg_peaks(filtered, sampling_rate=250, correct_artifacts=True, show=True)

#ECG_PLOT
nk.ecg_plot(signals,info)
normalized_filtered = filtered / np.max(np.abs(filtered))
ecg_plot.plot_1(normalized_filtered[:3000],sample_rate=250)
plt.show()
# Out:
# Requirement already satisfied: neurokit2 in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (0.2.10)
# Requirement already satisfied: seaborn in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (0.13.2)
# Requirement already satisfied: requests in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (from neurokit2) (2.32.3)
# Requirement already satisfied: numpy in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (from neurokit2) (1.26.4)
# Requirement already satisfied: pandas in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (from neurokit2) (2.2.2)
# Requirement already satisfied: scipy in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (from neurokit2) (1.13.1)
# Requirement already satisfied: scikit-learn>=1.0.0 in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (from neurokit2) (1.5.2)
# Requirement already satisfied: matplotlib in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (from neurokit2) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (from matplotlib->neurokit2) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (from matplotlib->neurokit2) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (from matplotlib->neurokit2) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (from matplotlib->neurokit2) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (from matplotlib->neurokit2) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (from matplotlib->neurokit2) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (from matplotlib->neurokit2) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (from matplotlib->neurokit2) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (from matplotlib->neurokit2) (6.4.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (from pandas->neurokit2) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (from pandas->neurokit2) (2023.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (from scikit-learn>=1.0.0->neurokit2) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (from scikit-learn>=1.0.0->neurokit2) (3.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (from requests->neurokit2) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (from requests->neurokit2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (from requests->neurokit2) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (from requests->neurokit2) (2024.8.30)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->neurokit2) (3.20.2)
# Requirement already satisfied: six>=1.5 in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (from python-dateutil>=2.7->matplotlib->neurokit2) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: neurokit2 in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (0.2.10)
# Requirement already satisfied: ecg-plot in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (0.2.8)
# Requirement already satisfied: requests in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (from neurokit2) (2.32.3)
# Requirement already satisfied: numpy in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (from neurokit2) (1.26.4)
# Requirement already satisfied: pandas in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (from neurokit2) (2.2.2)
# Requirement already satisfied: scipy in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (from neurokit2) (1.13.1)
# Requirement already satisfied: scikit-learn>=1.0.0 in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (from neurokit2) (1.5.2)
# Requirement already satisfied: matplotlib in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (from neurokit2) (3.9.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (from scikit-learn>=1.0.0->neurokit2) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (from scikit-learn>=1.0.0->neurokit2) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (from matplotlib->neurokit2) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (from matplotlib->neurokit2) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (from matplotlib->neurokit2) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (from matplotlib->neurokit2) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (from matplotlib->neurokit2) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (from matplotlib->neurokit2) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (from matplotlib->neurokit2) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (from matplotlib->neurokit2) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (from matplotlib->neurokit2) (6.4.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (from pandas->neurokit2) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (from pandas->neurokit2) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (from requests->neurokit2) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (from requests->neurokit2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (from requests->neurokit2) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (from requests->neurokit2) (2024.8.30)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->neurokit2) (3.20.2)
# Requirement already satisfied: six>=1.5 in c:\users\joaquin\miniconda3\envs\señales\lib\site-packages (from python-dateutil>=2.7->matplotlib->neurokit2) (1.16.0)
# c:\Users\Joaquin\miniconda3\envs\Señales\lib\site-packages\neurokit2\hrv\hrv_nonlinear.py:529: NeuroKitWarning: DFA_alpha2 related indices will not be calculated. The maximum duration of the windows provided for the long-term correlation is smaller than the minimum duration of windows. Refer to the `scale` argument in `nk.fractal_dfa()` for more information.
#   warn(
# <bound method DataFrame.reset_index of                                     0
# ECG_Rate_Mean               62.442086
# HRV_MeanNN      [[989.3142857142857]]
# HRV_SDNN       [[358.57089703259203]]
# HRV_SDANN1                    [[nan]]
# HRV_SDNNI1                    [[nan]]
# ...                               ...
# HRV_RCMSEn     [[1.4189677263593425]]
# HRV_CD         [[0.5123973226107402]]
# HRV_HFD        [[1.9416117766493501]]
# HRV_KFD         [[4.143058372617095]]
# HRV_LZC          [[1.05073423147628]]
#
# [83 rows x 1 columns]>
